# %% [markdown]
# Will analyse the correlation between Auto Stock 'Tesla as TSLA' and Oil stock 'Exxon Mobil as XOM'.

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import seaborn as sns
sns.set_style ('whitegrid')
import matplotlib.pyplot as plt
# %matplotlib inline
from pandas_datareader import data
from datetime import datetime

# %%
s= ['TSLA','XOM']
end= datetime.today()
start= datetime(end.year-1, end.month, end.day)
for stock in s:
    globals()[stock]= data.DataReader(stock,'google',start,end)
# Out:
# /Users/sera/Desktop/anaconda/lib/python3.5/site-packages/pandas_datareader/google/daily.py:40: UnstableAPIWarning:
# The Google Finance API has not been stable since late 2017. Requests seem
# to fail at random. Failure is especially common when bulk downloading.
#
#   warnings.warn(UNSTABLE_WARNING, UnstableAPIWarning)

# %%
XOM.describe()
# Out:
#              Open        High         Low       Close        Volume
# count  250.000000  251.000000  250.000000  251.000000  2.510000e+02
# mean    81.668360   82.108008   81.231160   81.660319  1.130440e+07
# std      2.634659    2.653669    2.669864    2.695360  5.156319e+06
# min     75.300000   76.440000   73.900000   74.890000  4.603210e+05
# 25%     80.440000   80.860000   80.145000   80.495000  8.684934e+06
# 50%     81.735000   82.180000   81.395000   81.760000  9.943991e+06
# 75%     82.945000   83.320000   82.510000   82.895000  1.233748e+07
# max     88.640000   89.300000   88.470000   89.070000  4.470493e+07

# %%
XOM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 251 entries, 2017-02-27 to 2018-02-23
# Data columns (total 5 columns):
# Open      250 non-null float64
# High      251 non-null float64
# Low       250 non-null float64
# Close     251 non-null float64
# Volume    251 non-null int64
# dtypes: float64(4), int64(1)
# memory usage: 11.8 KB

# %%
XOM['Close'].plot(legend= True, figsize=(10,4),color='pink')

# %%
TSLA['Close'].plot(legend=True, figsize= (10,4),color='pink')

# %%
closing_df = data.DataReader(['XOM','TSLA'],'google', start,end)['Close']
# Out:
# /Users/sera/Desktop/anaconda/lib/python3.5/site-packages/pandas_datareader/google/daily.py:40: UnstableAPIWarning:
# The Google Finance API has not been stable since late 2017. Requests seem
# to fail at random. Failure is especially common when bulk downloading.
#
#   warnings.warn(UNSTABLE_WARNING, UnstableAPIWarning)

# %%
s_rets= closing_df.pct_change()

# %%
sns.jointplot('XOM','TSLA',s_rets,kind='scatter', color='pink')
